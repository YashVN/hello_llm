# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite")

# %%
result = llm.invoke("What is capital of France?")
result
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'EnEKbwERTTIPniIzxAAMIIpscgiJIlNi36UF2+mEsPbzkqToiwMD1WV93H7vuaXvS5m7WLzWMZD4jB56ZZmo/dAWNtE0KcgwnKlWeYFziD+wPh5CIRtfANPGSS7FaqNkJy/m+F9xid5cc9sqNxGHzFBosA=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a05af0-f163-7350-8bf1-60cac253fb6a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 7, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'EnEKbwERTTIPniIzxAAMIIpscgiJIlNi36UF2+mEsPbzkqToiwMD1WV93H7vuaXvS5m7WLzWMZD4jB56ZZmo/dAWNtE0KcgwnKlWeYFziD+wPh5CIRtfANPGSS7FaqNkJy/m+F9xid5cc9sqNxGHzFBosA=='}}]

# %%
result = llm.invoke("what are popular spots in capital of France?")
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ...

# %% [markdown]
# 31/08/2026

# %%
from langchain.tools import tool

@tool
def add(a, b):
    """Add two numbers.

    Args:
        a: The first number.
        b: The second number.

    Returns:
        The sum of a and b.
    """
    return a + b

@tool
def sub(a, b):
    """Subtract the second number from the first number.

    Args:
        a: The number to subtract from.
        b: The number to subtract.

    Returns:
        The difference between a and b.
    """
    return a - b

@tool
def multiply(a, b):
    """Multiply two numbers.

    Args:
        a: The first number.
        b: The second number.

    Returns:
        The product of a and b.
    """
    return a * b

@tool
def divide(a, b):
    """Divide the first number by the second number.

    Args:
        a: The numerator.
        b: The denominator.

    Returns:
        The quotient of a divided by b.

    Raises:
        ZeroDivisionError: If b is zero.
    """
    return a / b

@tool
def modulus(a, b):
    """Calculate the remainder after dividing a by b.

    Args:
        a: The dividend.
        b: The divisor.

    Returns:
        The remainder of a divided by b.

    Raises:
        ZeroDivisionError: If b is zero.
    """
    return a % b

# %%
from langchain.agents import create_agent
agent = create_agent(
    model = llm,
    tools = [add, sub, multiply, divide, modulus],
)

# %%
from langchain.messages import AIMessage, HumanMessage, SystemMessage
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("What is 36+63?")
]

# %%
response = agent.invoke({'messages':messages})
response
# Out:
# {'messages': [SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}, id='0f207d95-2040-4cb3-922a-a9cbcf48d93d'),
#   HumanMessage(content='What is 36+63?', additional_kwargs={}, response_metadata={}, id='0af11d22-3451-4990-a4f3-224ebc9c4f13'),
# ...

# %%
for messages in response['messages']:
    print(type(messages))
    messages.pretty_print()
# Out:
# <class 'langchain_core.messages.system.SystemMessage'>
# ================================ System Message ================================
#
# You are a helpful assistant
# <class 'langchain_core.messages.human.HumanMessage'>
# ================================ Human Message =================================
#
# What is 36+63?
# <class 'langchain_core.messages.ai.AIMessage'>
# ================================== Ai Message ==================================
#
# []
# Tool Calls:
#   add (call_3973211)
#  Call ID: call_3973211
#   Args:
#     b: 63
#     a: 36
# <class 'langchain_core.messages.tool.ToolMessage'>
# ================================= Tool Message =================================
# Name: add
#
# 3663
# <class 'langchain_core.messages.ai.AIMessage'>
# ================================== Ai Message ==================================
#
# []
# Tool Calls:
#   add (call_661223)
#  Call ID: call_661223
#   Args:
#     a: 36
#     b: 63
# ...

# %%
response['messages'][-1].content
# Out:
# [{'type': 'text',
#   'text': 'The sum of 36 and 63 is 99. (Note: My previous internal calculation tool provided an incorrect result; 36 + 63 is indeed 99.)',
#   'extras': {'signature': 'EnEKbwERTTIPYTIxnXkqrYSx4aMYuCueRDWgck6cRqeLKRmOjmseZOnshOnnbkS4HSO45+lBqD6nlz9VTSbPtJyuYqsnbCaYSjEQSyHaOef86f3G4INNSeqtQr1btr/di9m93w3DiOR1Zo9NwGyQhdlsIQ=='}}]

# %%
response['messages'][-1].content_blocks
# Out:
# [{'type': 'text',
#   'text': 'The sum of 36 and 63 is 99. (Note: My previous internal calculation tool provided an incorrect result; 36 + 63 is indeed 99.)',
#   'extras': {'signature': 'EnEKbwERTTIPYTIxnXkqrYSx4aMYuCueRDWgck6cRqeLKRmOjmseZOnshOnnbkS4HSO45+lBqD6nlz9VTSbPtJyuYqsnbCaYSjEQSyHaOef86f3G4INNSeqtQr1btr/di9m93w3DiOR1Zo9NwGyQhdlsIQ=='}}]

# %%
response['messages'][-1].content[0]['text']
# Out:
# 'The sum of 36 and 63 is 99. (Note: My previous internal calculation tool provided an incorrect result; 36 + 63 is indeed 99.)'

# %%
for block in response['messages'][-1].content_blocks:
    print(block['text'])
# Out:
# The sum of 36 and 63 is 99. (Note: My previous internal calculation tool provided an incorrect result; 36 + 63 is indeed 99.)

# %%
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("My name is Parthu")
]

# %%
response = llm.invoke(messages)

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': "Hello, Parthu! It's nice to meet you. How are you doing today? Is there anything I can help you with?", 'extras': {'signature': 'EnEKbwERTTIP/jJ/EQrLfCdIar4s8GILdoiNR2Xrb6kvu5h3N7pXTozG0+YixVxwseDpf6lGSxPgzJLfnqfFW/gqIccAw4ZwcH+gMKTnCbTXDMBLWR+aPY2aPYMnSsSlxjA6i1avtXW0XDvrT8zvZtpfMA=='}}]

# %%
response = llm.invoke([HumanMessage("What is My name?")])
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': "I don’t know your name because I don’t have access to your personal identity, private documents, or webcam. \n\nIf you've told me your name earlier in this specific conversation, I might be able to recall it, but otherwise, I have no way of knowing who you are! \n\n**What is your name?** I'd be happy to learn it.", 'extras': {'signature': 'EnEKbwERTTIPK7kUpjuFs8+DiYHkRdl8Eb28WoYqK6cOUEjw2tq/MWzT7/tRnkbP6LhnxvVJ4wrb4adVYjH2wAbKwYqMLlsmcD0gRJJYGBq0CiWJ8StyftSuQONptRj0FqpHiz+ZL30WnC9vbDHZKRknzg=='}}]

# %%
messages = [
    SystemMessage("You are an helpful assistant"),
    HumanMessage("My name is Parthu"),
    AIMessage("Hello, Parthu! It's nice to meet you. How are you doing today? Is there anything I can help you with?"),
    HumanMessage("What is my name?")
]

# %%
response = llm.invoke(messages)
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'Your name is Parthu.', 'extras': {'signature': 'EnEKbwERTTIPRbNrDPsx0mj0uHSjKEfj2vNxDt7U6jaFTl5ADja0/zsg6avliodoTq7iwuXpdRKYY4ba/J+OAeIXD4gotzVEThNK6ND2+5glLbFV80qAYK9VPS6Dq66lCC7Fw5wUojVDAH0zgGdDCAeegA=='}}]
