# %%
from langchain.chat_models import init_chat_model,BaseChatModel
from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
model_name = 'google_genai:gemini-3.1-flash-lite'

# %%
model = init_chat_model(model_name)

# %%
from langchain.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("human", "what is the capital of {country}?")
])

# %%
model.invoke("what is capital of France?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'EnEKbwERTTIP3L+Or/wa4IAXyfwbchl7PPwJnwqe66azf+U8ruY5AI4nvfhRRUsoH++GC+00g2oy1SSXZtzaMBb6mROgrLjqdL6mfIMvdrXvbVs++g/ieXkgipQkpTZOydh4eYQHesOHwRlj4NfyEVVgwA=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a086ff-36f2-73b1-ae41-6169ccb03eb3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 8, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}})

# %%
chain = prompt_template | model
type(chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %%
chain.invoke({
    "country":"France"
})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'EnEKbwERTTIPO41Ed1tD+lO3L4QtKE/HRNdqWRmOji5eTtpC1XiKhnRAQLGdmNcrw1s+ahi7OcDffVMe0zKZuMQOlEI9+BG2fncp4VBq+WdP101WYaHtvDpR4NvplhNVy/FiQvxm/Ml0H9OZ2OIqJgwlhw=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a086ff-fe4a-7e20-9fe9-e9730b385894-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 7, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}})
